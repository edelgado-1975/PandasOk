# %% [markdown]
# <a href="https://colab.research.google.com/github/edelgado-1975/PandasOk/blob/main/Taller_Pandas_Matplolib2resuelto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TALLER DE PANDAS + MATPLOID
#
# Crear el DataFrame: Con datos de futbolistas, incluyendo nombre, apellido, liga, salario, temporada y goles.
# Análisis de Datos:
#
# 1.Jugador que más goles efectuó.
# 2.Tres primeros jugadores por temporada.
# 3.Ranking de jugadores ordenados por goles.
# 4.Visualización de Datos:
# 5.Gráfico de barras: Goles por jugador.
# 6.Gráfico de caja (boxplot): Distribución de goles por temporada.
# 7.Gráfico de dispersión: Relación entre salario y goles.

# %%
"""Paso 1: Crear el DataFrame
Primero, vamos a crear un DataFrame con datos de futbolistas."""
import pandas as pd

# Crear el DataFrame
data = {
    'Nombre': ['Lionel', 'Cristiano', 'Neymar', 'Kylian', 'Robert', 'Kevin', 'Virgil', 'Sergio', 'Eden', 'Mohamed'],
    'Apellido': ['Messi', 'Ronaldo', 'Neymar', 'Mbappe', 'Lewandowski', 'De Bruyne', 'Van Dijk', 'Ramos', 'Hazard', 'Salah'],
    'Liga': ['La Liga', 'Serie A', 'Ligue 1', 'Ligue 1', 'Bundesliga', 'Premier League', 'Premier League', 'La Liga', 'La Liga', 'Premier League'],
    'Salario': [65000000, 54000000, 36000000, 35000000, 45000000, 33000000, 25000000, 30000000, 25000000, 20000000],
    'Temporada': [2022, 2023, 2023, 2022, 2022, 2024, 2022, 2022, 2022, 2022],
    'Goles': [30, 28, 22, 25, 35, 18, 12, 15, 10, 20]
}

df = pd.DataFrame(data)
df.head() # Muestra la tabla con los primeros 5 registros
# Out:
#       Nombre     Apellido        Liga   Salario  Temporada  Goles
# 0     Lionel        Messi     La Liga  65000000       2022     30
# 1  Cristiano      Ronaldo     Serie A  54000000       2023     28
# 2     Neymar       Neymar     Ligue 1  36000000       2023     22
# 3     Kylian       Mbappe     Ligue 1  35000000       2022     25
# 4     Robert  Lewandowski  Bundesliga  45000000       2022     35

# %%
"""Paso 2: Análisis de Datos
2.1. Jugador que más goles efectuó"""
# Jugador con más goles
top_scorer = df.loc[df['Goles'].idxmax()]
print("Jugador con más goles:")
print(top_scorer)
# Out:
# Jugador con más goles:
# Nombre            Robert
# Apellido     Lewandowski
# Liga          Bundesliga
# Salario         45000000
# Temporada           2022
# Goles                 35
# Name: 4, dtype: object

# %%
"""2.2. Tres primeros jugadores por temporada"""
# Tres jugadores con más goles por temporada
top_3_players = df.groupby('Temporada').apply(lambda x: x.nlargest(3, 'Goles')).reset_index(drop=True)
print("Tres primeros jugadores por temporada:")
print(top_3_players)


"""La advertencia que estás viendo indica que el uso de apply en combinación con groupby
está operando en las columnas de agrupación, y esta práctica está siendo desalentada en versiones
recientes de pandas. Esta advertencia sugiere que en el futuro, el comportamiento podría cambiar
y que es mejor ajustar el código para evitar posibles problemas futuros."""
# Out:
# Tres primeros jugadores por temporada:
#       Nombre     Apellido        Liga   Salario  Temporada  Goles
# 0     Robert  Lewandowski  Bundesliga  45000000       2022     35
# 1     Lionel        Messi     La Liga  65000000       2022     30
# 2  Cristiano      Ronaldo     Serie A  54000000       2022     28
# 'La advertencia que estás viendo indica que el uso de apply en combinación con groupby\nestá operando en las columnas de agrupación, y esta práctica está siendo desalentada en versiones\nrecientes de pandas. Esta advertencia sugiere que en el futuro, el comportamiento podría cambiar\ny que es mejor ajustar el código para evitar posibles problemas futuros.'

# %%
"""Paso 3: Visualización de Datos goles por jugador"""
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.barh(df['Nombre'] + ' ' + df['Apellido'], df['Goles'], color='skyblue', edgecolor='black')
plt.xlabel('Goles')
plt.ylabel('Jugador')
plt.title('Goles por Jugador')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
"""3.2. Gráfico de distribución de goles por temporada"""
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(x='Temporada', y='Goles', data=df, palette='pastel')
plt.xlabel('Temporada')
plt.ylabel('Goles')
plt.title('Distribución de Goles por Temporada')
plt.grid(True)
plt.show()


"""La advertencia que estás viendo sugiere que la forma en que estás usando
el parámetro palette en sns.boxplot cambiará en una versión futura de seaborn.
En versiones futuras (a partir de la 0.14.0), pasar palette sin usar hue será obsoleto.
La advertencia te aconseja asignar el parámetro x a hue y desactivar la leyenda si deseas el
mismo efecto estético."""
# Out:
# C:\Users\SENA\AppData\Local\Temp\ipykernel_22160\962999618.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Temporada', y='Goles', data=df, palette='pastel')

# %%
"""3.3. Gráfico de salarios vs. goles"""
plt.figure(figsize=(12, 6))
plt.scatter(df['Goles'], df['Salario'], color='green', edgecolor='black', alpha=0.7)
plt.ylabel('Salario')
plt.xlabel('Goles')
plt.title('Relación entre Salario y Goles')
plt.grid(True)
plt.show()

# %% [markdown]
# TRABAJEMOS EN CLASE PARA CONSTRUIR:
#
# Jugadores con Mayor Salario
# 1. Jugadores por Liga
# 2. Jugadores con Mayor Salario
# 3. Goles Totales por Temporada
# 4. Promedio de Goles por Jugador
# 5. Goles Maximos y Minimos Por Liga
#
#
# Ahora la cereza del pastel... los graficos
#
# 1. Gráfico de Dispersión de Salario vs. Goles Propósito: Analizar la relación entre el salario y el número de goles.
# 2. Gráfico de Barras de Goles por Liga Propósito: Comparar el número total de goles por cada liga.
# 3. Gráfico de Torta (Pastel) de Goles por Liga Propósito: Visualizar la proporción de goles en cada liga.
# 4. Gráfico de Violín de Goles por Liga Propósito: Ver la distribución de los goles en cada liga.
# 5. Gráfico de Contorno de Goles vs. Salario Propósito: Mostrar la densidad de puntos en el espacio de goles vs. salario.
# 6. Gráfico de Superficie de Goles vs. Salario por Temporada Propósito: Ver la relación de goles y salario en diferentes temporadas en un gráfico tridimensional.

# %%
"""Jugadores por Liga"""
players_by_league = df.groupby('Liga').size().reset_index(name='Número de Jugadores')
print("Número de jugadores por liga:")
print(players_by_league)
# Out:
# Número de jugadores por liga:
#              Liga  Número de Jugadores
# 0      Bundesliga                    1
# 1         La Liga                    3
# 2         Ligue 1                    2
# 3  Premier League                    3
# 4         Serie A                    1

# %%
"""Jugadores con Mayor Salario"""
top_salary_players = df.sort_values(by='Salario', ascending=False).reset_index(drop=True)
print("Jugadores con el mayor salario:")
print(top_salary_players)
# Out:
# Jugadores con el mayor salario:
#       Nombre     Apellido            Liga   Salario  Temporada  Goles
# 0     Lionel        Messi         La Liga  65000000       2022     30
# 1  Cristiano      Ronaldo         Serie A  54000000       2022     28
# 2     Robert  Lewandowski      Bundesliga  45000000       2022     35
# 3     Neymar       Neymar         Ligue 1  36000000       2022     22
# 4     Kylian       Mbappe         Ligue 1  35000000       2022     25
# 5      Kevin    De Bruyne  Premier League  33000000       2022     18
# 6     Sergio        Ramos         La Liga  30000000       2022     15
# 7     Virgil     Van Dijk  Premier League  25000000       2022     12
# 8       Eden       Hazard         La Liga  25000000       2022     10
# 9    Mohamed        Salah  Premier League  20000000       2022     20

# %%
"""Ver la suma total de goles en cada temporada."""

total_goals_by_season = df.groupby('Temporada')['Goles'].sum().reset_index()
print("Goles totales por temporada:")
print(total_goals_by_season)
# Out:
# Goles totales por temporada:
#    Temporada  Goles
# 0       2022    147
# 1       2023     50
# 2       2024     18

# %%
"""Promedio de Goles por Jugador"""
avg_goals_per_player = df['Goles'].mean()
print(f"Promedio de goles por jugador: {avg_goals_per_player:.2f}")
# Out:
# Promedio de goles por jugador: 21.50

# %%
"""Encontrar el máximo y mínimo de goles en cada liga"""
goals_extremes_by_league = df.groupby('Liga').agg({'Goles': ['max', 'min']}).reset_index()
goals_extremes_by_league.columns = ['Liga', 'Goles Máximos', 'Goles Mínimos']
print("Goles máximos y mínimos por liga:")
print(goals_extremes_by_league)
# Out:
# Goles máximos y mínimos por liga:
#              Liga  Goles Máximos  Goles Mínimos
# 0      Bundesliga             35             35
# 1         La Liga             30             10
# 2         Ligue 1             25             22
# 3  Premier League             20             12
# 4         Serie A             28             28

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['Goles'], df['Salario'], color='purple', edgecolor='black', alpha=0.7)
plt.ylabel('Salario')
plt.xlabel('Goles')
plt.title('Relación entre Salario y Goles')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.barplot(x='Liga', y='Goles', data=df, estimator='sum', palette='viridis')
plt.xlabel('Liga')
plt.ylabel('Total de Goles')
plt.title('Total de Goles por Liga')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-24-31be5107a63f>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Liga', y='Goles', data=df, estimator='sum', palette='viridis')

# %%
plt.figure(figsize=(4, 4))
league_goals = df.groupby('Liga')['Goles'].sum()
plt.pie(league_goals, labels=league_goals.index, autopct='%1.1f%%', colors=sns.color_palette('Set2'), startangle=140)
plt.title('Proporción de Goles por Liga')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='Liga', y='Goles', data=df, palette='coolwarm')
plt.xlabel('Liga')
plt.ylabel('Goles')
plt.title('Distribución de Goles por Liga')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# <ipython-input-29-87e47ce49b56>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Liga', y='Goles', data=df, palette='coolwarm')

# %%
import numpy as np
import seaborn as sns
plt.figure(figsize=(12, 6))
x = df['Salario']
y = df['Goles']
sns.kdeplot(x=x, y=y, cmap='Blues', fill=True)
plt.xlabel('Salario')
plt.ylabel('Goles')
plt.title('Densidad de Goles vs. Salario')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

# Preparar datos
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
x = df['Salario']
y = df['Goles']
z = df['Temporada']

# Crear gráfico de superficie
img = ax.scatter(x, y, z, c=z, cmap='viridis')
fig.colorbar(img, ax=ax, label='Temporada')
ax.set_xlabel('Salario')
ax.set_ylabel('Goles')
ax.set_zlabel('Temporada')
ax.set_title('Relación entre Salario, Goles y Temporada')
plt.show()
